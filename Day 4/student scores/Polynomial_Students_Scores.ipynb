# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %%
# read Salary data
df = pd.read_csv('/content/student_scores.csv')

# %%
#plot some of orginal data
plt.scatter(df['Hours'],df['Scores'])
plt.xlabel('Hours')
plt.ylabel('Scores')
plt.show()

# %%
from sklearn.preprocessing import PolynomialFeatures
from sklearn.linear_model import LinearRegression

# Assuming the previous code (reading data, fitting the model) has been executed

# Generate a smoother curve for visualization
X_grid = np.arange(min(X['Hours']), max(X['Hours']), 0.1)
X_grid = X_grid.reshape(len(X_grid), 1)

# %%
plt.scatter(X, y, color='red', label='Actual Data') # Plot actual data points
plt.plot(X_grid, model.predict(poly_reg.fit_transform(X_grid)), color='blue', label='Polynomial Regression') # Plot the polynomial fit

plt.title('Truth or Bluff (Polynomial Regression)')
plt.xlabel('Hours')
plt.ylabel('Scores')
plt.legend() # Show legend for clarity
plt.show()
