# %%
import pandas as pd
df=pd.read_csv('diabetes.csv')
df
# Out:
#      Pregnancies  Glucose  BloodPressure  SkinThickness  Insulin   BMI  \
# 0              6      148             72             35        0  33.6
# 1              1       85             66             29        0  26.6
# 2              8      183             64              0        0  23.3
# 3              1       89             66             23       94  28.1
# 4              0      137             40             35      168  43.1
# ..           ...      ...            ...            ...      ...   ...
# 763           10      101             76             48      180  32.9
# 764            2      122             70             27        0  36.8
# 765            5      121             72             23      112  26.2
# 766            1      126             60              0        0  30.1
# 767            1       93             70             31        0  30.4
#
#      DiabetesPedigreeFunction  Age  Outcome
# 0                       0.627   50        1
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 768 entries, 0 to 767
# Data columns (total 9 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   Pregnancies               768 non-null    int64
#  1   Glucose                   768 non-null    int64
#  2   BloodPressure             768 non-null    int64
#  3   SkinThickness             768 non-null    int64
#  4   Insulin                   768 non-null    int64
#  5   BMI                       768 non-null    float64
#  6   DiabetesPedigreeFunction  768 non-null    float64
#  7   Age                       768 non-null    int64
#  8   Outcome                   768 non-null    int64
# dtypes: float64(2), int64(7)
# memory usage: 54.1 KB

# %%
X= df.drop(['Outcome'],axis=1)
y= df['Outcome']
from sklearn.model_selection import train_test_split
x_train , x_test , y_train , y_test = train_test_split(X , y , test_size=0.3 , random_state=42)
from sklearn.linear_model import LogisticRegression
from sklearn.ensemble import RandomForestClassifier
from sklearn.neighbors import KNeighborsClassifier
from sklearn.tree import DecisionTreeClassifier
from sklearn.svm import SVC
dic={
    'LogisticRegression':LogisticRegression(),
    'RandomeForestClassifier':RandomForestClassifier(max_depth=5, n_estimators=7, random_state=0),
    'KNeighborsClassifier':KNeighborsClassifier(n_neighbors=3,metric='manhattan'),
    'DecisionTreeClassifier':DecisionTreeClassifier(criterion='entropy', max_depth=2),
    'Support Vector Machine':SVC(kernel='linear'),
}

from sklearn.metrics import accuracy_score,classification_report,confusion_matrix
def accuracy(y_test,y_pred):
    acc = accuracy_score(y_test,y_pred)
    return acc
    
accuracy_models=[]

models_names = []
for model_name , model in dic.items():
    model.fit(x_train,y_train)
    y_pred = model.predict(x_test)
    accuracy_models.append(accuracy(y_test,y_pred))
    models_names.append(model_name)
    print(classification_report(y_test,y_pred))
    print(confusion_matrix(y_test,y_pred))
    print('++++++++++++++++++++++++++++++++++++++')
# Out:
# C:\Users\Moga\anaconda3\Lib\site-packages\sklearn\linear_model\_logistic.py:469: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
#               precision    recall  f1-score   support
#
#            0       0.80      0.80      0.80       151
#            1       0.62      0.62      0.62        80
#
#     accuracy                           0.74       231
#    macro avg       0.71      0.71      0.71       231
# weighted avg       0.74      0.74      0.74       231
#
# [[121  30]
#  [ 30  50]]
# ++++++++++++++++++++++++++++++++++++++
#               precision    recall  f1-score   support
#
# ...

# %%
accuracy_df = pd.DataFrame()
accuracy_df['models'] =models_names
accuracy_df['Accuray'] =accuracy_models
accuracy_df = accuracy_df.set_index('models')
accuracy_df
# Out:
#                           Accuray
# models
# LogisticRegression       0.740260
# RandomeForestClassifier  0.722944
# KNeighborsClassifier     0.679654
# DecisionTreeClassifier   0.718615
# Support Vector Machine   0.744589

# %%
from sklearn.preprocessing import MinMaxScaler
scaler = MinMaxScaler()
X_scaler = scaler.fit_transform(X)
from sklearn.model_selection import train_test_split
x_train,x_test ,y_train,y_test = train_test_split(X_scaler,y ,test_size=0.1,shuffle=True,stratify=y)
from sklearn.linear_model import LogisticRegression
from sklearn.ensemble import RandomForestClassifier
from sklearn.neighbors import KNeighborsClassifier
from sklearn.tree import DecisionTreeClassifier
from sklearn.svm import SVC
dic={
    'LogisticRegression':LogisticRegression(),
    'RandomeForestClassifier':RandomForestClassifier(max_depth=5, n_estimators=7, random_state=0),
    'KNeighborsClassifier':KNeighborsClassifier(n_neighbors=3,metric='manhattan'),
    'DecisionTreeClassifier':DecisionTreeClassifier(criterion='entropy', max_depth=2),
    'Support Vector Machine':SVC(kernel='linear'),
}

from sklearn.metrics import accuracy_score,classification_report,confusion_matrix
def accuracy(y_test,y_pred):
    acc = accuracy_score(y_test,y_pred)
    return acc
    
accuracy_models=[]

models_names = []
for model_name , model in dic.items():
    model.fit(x_train,y_train)
    y_pred = model.predict(x_test)
    accuracy_models.append(accuracy(y_test,y_pred))
    models_names.append(model_name)
    print(classification_report(y_test,y_pred))
    print(confusion_matrix(y_test,y_pred))
    print('++++++++++++++++++++++++++++++++++++++')
# Out:
#               precision    recall  f1-score   support
#
#            0       0.76      0.90      0.83        50
#            1       0.72      0.48      0.58        27
#
#     accuracy                           0.75        77
#    macro avg       0.74      0.69      0.70        77
# weighted avg       0.75      0.75      0.74        77
#
# [[45  5]
#  [14 13]]
# ++++++++++++++++++++++++++++++++++++++
#               precision    recall  f1-score   support
#
#            0       0.81      0.88      0.85        50
#            1       0.74      0.63      0.68        27
#
#     accuracy                           0.79        77
#    macro avg       0.78      0.75      0.76        77
# weighted avg       0.79      0.79      0.79        77
#
# [[44  6]
#  [10 17]]
# ++++++++++++++++++++++++++++++++++++++
#               precision    recall  f1-score   support
#
#            0       0.76      0.82      0.79        50
#            1       0.61      0.52      0.56        27
#
# ...

# %%
accuracy_df = pd.DataFrame()
accuracy_df['models'] =models_names
accuracy_df['Accuray'] =accuracy_models
accuracy_df = accuracy_df.set_index('models')
accuracy_df
# Out:
#                           Accuray
# models
# LogisticRegression       0.753247
# RandomeForestClassifier  0.792208
# KNeighborsClassifier     0.714286
# DecisionTreeClassifier   0.779221
# Support Vector Machine   0.740260
