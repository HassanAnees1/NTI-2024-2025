# %%
import numpy as np
import pandas as pd
from matplotlib import pyplot as plt
from scipy.cluster.hierarchy import dendrogram
from sklearn.cluster import AgglomerativeClustering

# %%
data=pd.read_csv('/content/cluster.csv')
data
# Out:
#   Unnamed: 0    P1    P2    P3    P4    P5
# 0         P1  1.00  0.10  0.41  0.55  0.35
# 1         P2  0.10  1.00  0.64  0.47  0.98
# 2         P3  0.41  0.64  1.00  0.44  0.85
# 3         P4  0.55  0.47  0.44  1.00  0.76
# 4         P5  0.35  0.98  0.85  0.76  1.00

# %%
#setting distance _threshold =0 ensures we compute the full tree
model = AgglomerativeClustering(distance_threshold=0, linkage='single',n_clusters=None)

# %%
model
# Out:
# AgglomerativeClustering(distance_threshold=0, linkage='single', n_clusters=None)

# %%
import numpy as np
import pandas as pd
from matplotlib import pyplot as plt
from scipy.cluster.hierarchy import dendrogram
from sklearn.cluster import AgglomerativeClustering

# Load your data
data = pd.read_csv('/content/CLUSTER2.csv')

# Assuming the first column contains labels, exclude it from clustering
X = data.iloc[:, 1:] # Select all columns except the first

# Create the AgglomerativeClustering model
model = AgglomerativeClustering(distance_threshold=0, linkage='single', n_clusters=None)

# Fit the model to the numerical features
model = model.fit(X)

# Now you can access the children_ attribute and plot the dendrogram
plt.title('Hierarchical clustering dendrogram')
label_list = ["P1", "P2", "P3", "P4", "P5"]  # Assuming these are your labels
plot_dendrogram(model, truncate_mode="level", p=3, labels=label_list)
plt.xlabel("number of points in node (or index of point if no parenthesis).")
plt.show()
